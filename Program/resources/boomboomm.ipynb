# %% [markdown]
# ### Please run the following cell once.
#
# This will install the Apache Bahir connector within your Project/Apache Spark service. If you restart the kernel or start a new notebook in the same project you can use Apache Bahir for connecting to the Cloudant/Apache CouchDB service. Please note that this will install a patched version of the connector (since the pull request hasn't been merged with the trunk yet).
#
# You'll find more information on the patch here:
#
# https://github.com/apache/bahir/pull/49 https://issues.apache.org/jira/browse/BAHIR-130

# %%
# !pip install cloudant
# Out:
# Collecting cloudant
#   Downloading https://files.pythonhosted.org/packages/ed/46/e0935c7be2452fd923606c97122fedf8793731cd306f79e185082a641adb/cloudant-2.13.0-py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 7.7MB/s eta 0:00:011
# Requirement already satisfied: requests<3.0.0,>=2.7.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from cloudant) (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests<3.0.0,>=2.7.0->cloudant) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests<3.0.0,>=2.7.0->cloudant) (2020.6.20)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests<3.0.0,>=2.7.0->cloudant) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests<3.0.0,>=2.7.0->cloudant) (2.8)
# Installing collected packages: cloudant
# Successfully installed cloudant-2.13.0

# %%
#PLEASE INSERT TO CREDENTIALS TO CLOUDANT HERE USING THE IBM WATSON STUDIO CONNECTIONS TAB RIGHT TO THIS NOTEBOOK
# @hidden_cell
# The following code contains the credentials for a connection in your Project.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'username': 'dfedf099-aea1-4ef3-af47-5017237413a2-bluemix',
    'password': """ea2b58dfc9708d7ac08916ed8dc1f9785da00f9b4c9923ae7f7fe59e8200f1a0""",
    'custom_url': 'https://dfedf099-aea1-4ef3-af47-5017237413a2-bluemix:ea2b58dfc9708d7ac08916ed8dc1f9785da00f9b4c9923ae7f7fe59e8200f1a0@dfedf099-aea1-4ef3-af47-5017237413a2-bluemix.cloudantnosqldb.appdomain.cloud',
    'port': '50000',
}

# %%
from cloudant.client import Cloudant
from cloudant.error import CloudantException
from cloudant.result import Result, ResultByKey

serviceUsername= credentials_1['username']
servicePassword= credentials_1['password']
serviceURL=credentials_1['custom_url']
cloudantName='ddd'

client = Cloudant(serviceUsername, servicePassword, url=serviceURL)
client.connect()

# %%
df=client[cloudantName]

#for doc in df:
#    print(doc)
# Out:
# {'_id': '294e35032b37dfe300e00a5a4b3ae05e', '_rev': '1-ab84dc739d55ad8ec59dfa23b36a1eff', 'X': 0.1, 'Y': 0.1, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': '294e35032b37dfe300e00a5a4b3b0690', '_rev': '1-04a1f01ec1e5805f9cf03164663a85e6', 'X': 2.22, 'Y': -2.17, 'Z': 1.78, 'SENSORID': '1'}
# {'_id': '294e35032b37dfe300e00a5a4b3b1485', '_rev': '1-0e00a566167cb848b1866531a7894f8e', 'X': 2.16, 'Y': -2.08, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': '294e35032b37dfe300e00a5a4b3b2972', '_rev': '1-19570129b90fa4da9f8d04f3f779c70c', 'X': -0.1, 'Y': -1.04, 'Z': 1.46, 'SENSORID': '1'}
# {'_id': '835e3449e09b70115900b42ead6533ef', '_rev': '1-18c182329568a20482a9c01baef3c5b3', 'X': 0.1, 'Y': -0.75, 'Z': 1.32, 'SENSORID': '1'}
# {'_id': '835e3449e09b70115900b42ead657c9e', '_rev': '1-072006caf6b55ba42fa975dfe0062301', 'X': -2.2, 'Y': -8.5, 'Z': -16.5, 'SENSORID': '2'}
# {'_id': '835e3449e09b70115900b42ead658605', '_rev': '1-9a69ac7c2e2edc91a3f08a3f78b3588e', 'X': -1.2, 'Y': -7.5, 'Z': 32.2, 'SENSORID': '2'}
# {'_id': '9d2003b59e4a0349fb5273a5683dab19', '_rev': '1-a5541591b5fe5072772c2a3ac30af6e1', 'X': 2.49, 'Y': -3.06, 'Z': 0.3, 'SENSORID': '1'}
# {'_id': '9d2003b59e4a0349fb5273a5683db5af', '_rev': '1-92b8759966c39690fb764deb929ef69a', 'X': 2.32, 'Y': -2.3, 'Z': 1.85, 'SENSORID': '1'}
# {'_id': '9d2003b59e4a0349fb5273a5683dd390', '_rev': '1-d5847ba68cc34c4dfd0bda6fb2cea3a8', 'X': -0.1, 'Y': -2.26, 'Z': -0.1, 'SENSORID': '1'}
# {'_id': '9d2003b59e4a0349fb5273a5683de8b4', '_rev': '1-8a48fb277a942c0ef99635e9b2dbe268', 'X': 0.1, 'Y': -2.02, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': '9d2003b59e4a0349fb5273a5683de8c6', '_rev': '1-24ee2b6249294a6f19fc73d8d412acbf', 'X': 1.81, 'Y': -1.62, 'Z': -0.1, 'SENSORID': '1'}
# {'_id': '9d2003b59e4a0349fb5273a5683de936', '_rev': '1-b7d7da899fb04e0f99f658fcd3871b9e', 'X': -0.1, 'Y': -0.1, 'Z': 1.49, 'SENSORID': '1'}
# {'_id': '9d2003b59e4a0349fb5273a5683df4e1', '_rev': '1-3957ae6485225a5becf1c5e05a84992f', 'X': 1.52, 'Y': -1.05, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': '9d2003b59e4a0349fb5273a5683e2bc2', '_rev': '1-67ae29864fb17b3f1a816abd8e5ced33', 'X': 1.3, 'Y': -0.72, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'a9035176c352d178a51118fd980f53c9', '_rev': '1-280e5a9cc848fc2f95e6dc4cbaee5a88', 'X': 0.1, 'Y': 0.2, 'Z': -0.1, 'SENSORID': '1'}
# {'_id': 'a9035176c352d178a51118fd980f64fe', '_rev': '1-38c8ae25f3feaf125f08e10e0c3745d7', 'X': 2.31, 'Y': -2.38, 'Z': -0.2, 'SENSORID': '1'}
# {'_id': 'a9035176c352d178a51118fd980fa625', '_rev': '1-89e5ee2a94191cb2a83a022ca37a49e9', 'X': 1.83, 'Y': -0.1, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'a9035176c352d178a51118fd980fa876', '_rev': '1-6bca27512b37311a7d0f225c7b1cb716', 'X': 1.56, 'Y': -1.25, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'a9035176c352d178a51118fd981025e4', '_rev': '1-dda159334a3decaa02e671185df9578f', 'X': -1.3, 'Y': -8.3, 'Z': -44.1, 'SENSORID': '2'}
# {'_id': 'a9035176c352d178a51118fd981027d5', '_rev': '1-fc397b95e9b8c69dce566826fd3e6d84', 'X': -0.1, 'Y': -14.7, 'Z': 33.7, 'SENSORID': '2'}
# {'_id': 'a9035176c352d178a51118fd98102ace', '_rev': '1-4663ddb28c5be305f8963957e6f2ec2f', 'X': -0.1, 'Y': -1.6, 'Z': -0.1, 'SENSORID': '2'}
# {'_id': 'b8bd4216d991da18183bd5c538907015', '_rev': '1-2aa3220825e33d7589ee87e65f5543df', 'X': 0.1, 'Y': 0.2, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c53890a550', '_rev': '1-4d39bc564ef4afce3c23ffcbe0fc7f86', 'X': 2.08, 'Y': -1.96, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c53890a7c7', '_rev': '1-3662d95f4a02b2a0f83801ff1f7d97c2', 'X': -0.1, 'Y': -1.8, 'Z': 1.68, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c53890b225', '_rev': '1-810de6fc59ee5d5077c24e0c0aae9cae', 'X': -0.1, 'Y': -1.54, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c53890b2cd', '_rev': '1-839ee51d737c1286a1c8af8304cefbbb', 'X': 1.7, 'Y': -1.55, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c53890b791', '_rev': '1-4d2991a9395d56bd1be0c40b21341a5b', 'X': 1.63, 'Y': -1.41, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c53890bd25', '_rev': '1-d3bb12a99130f7007446de14bd259cb9', 'X': 1.43, 'Y': 0.1, 'Z': 1.41, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c53890ffc4', '_rev': '1-06fb71ddcfc30db8884da439f1efc251', 'X': 1.22, 'Y': 0.1, 'Z': -0.1, 'SENSORID': '1'}
# {'_id': 'b8bd4216d991da18183bd5c538915465', '_rev': '1-295f8af0f9d2b679b19eea52089377bd', 'X': -6.2, 'Y': -4.6, 'Z': 52.2, 'SENSORID': '2'}
# {'_id': 'd9ef15b1032014468c5bead8d1b0ab8f', '_rev': '1-04b38a41ba29195f1a98be828cfdee0c', 'X': 2.48, 'Y': 0.1, 'Z': -0.3, 'SENSORID': '1'}
# {'_id': 'd9ef15b1032014468c5bead8d1b0dfe1', '_rev': '1-b3b816a8ed8931af76a5d6374f873268', 'X': 2.2, 'Y': 0.1, 'Z': -0.1, 'SENSORID': '1'}
# {'_id': 'd9ef15b1032014468c5bead8d1b10124', '_rev': '1-281a385f8de313a8e2dce28d266007c0', 'X': 1.73, 'Y': -1.49, 'Z': 1.6, 'SENSORID': '1'}
# {'_id': 'd9ef15b1032014468c5bead8d1b101dc', '_rev': '1-54cf55caa57b18218cd06695339fd8a7', 'X': -0.1, 'Y': -0.1, 'Z': 1.53, 'SENSORID': '1'}
# {'_id': 'd9ef15b1032014468c5bead8d1b10ca0', '_rev': '1-00d6a2c93098cf740d92416f57bdc1cd', 'X': -0.1, 'Y': -0.1, 'Z': 1.44, 'SENSORID': '1'}
# {'_id': 'd9ef15b1032014468c5bead8d1b11a7d', '_rev': '1-3ee7833efe47e597c7d0e0843145bede', 'X': 1.41, 'Y': -1.24, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'd9ef15b1032014468c5bead8d1b176d2', '_rev': '1-b6e895b79f325544318019fe20782e8a', 'X': -2.6, 'Y': -17.5, 'Z': -19.8, 'SENSORID': '2'}
# {'_id': 'e77648716042c27c8b610e27c2487d81', '_rev': '1-70675dc3095e272d678bc4f144b365ee', 'X': 1.85, 'Y': -1.67, 'Z': 1.66, 'SENSORID': '1'}
# {'_id': 'e77648716042c27c8b610e27c2488527', '_rev': '1-310ed5f50ede2e07aa5a127e3089baf4', 'X': 1.68, 'Y': -1.4, 'Z': 1.59, 'SENSORID': '1'}
# {'_id': 'e77648716042c27c8b610e27c2488ec5', '_rev': '1-b513c65da10032dbc8b8edf2aa4eb5be', 'X': 1.65, 'Y': -1.35, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'e77648716042c27c8b610e27c24895ff', '_rev': '1-2a1eab17676b4298d767efaf26e34f71', 'X': 1.54, 'Y': -1.11, 'Z': 1.5, 'SENSORID': '1'}
# {'_id': 'e77648716042c27c8b610e27c248a0ef', '_rev': '1-5c410944f6174e1bba2ac30c91b3a547', 'X': -0.1, 'Y': -1.07, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'e77648716042c27c8b610e27c248a28b', '_rev': '1-ab84dc739d55ad8ec59dfa23b36a1eff', 'X': 0.1, 'Y': 0.1, 'Z': 0.1, 'SENSORID': '1'}
# {'_id': 'e77648716042c27c8b610e27c248fd1c', '_rev': '1-b9a12008317a47cf3841ca3d0a9b2f4f', 'X': -0.1, 'Y': -0.67, 'Z': 1.31, 'SENSORID': '1'}

# %%
from numpy.lib.scimath import sqrt
from pprint import pprint as pp


energy=dict()

# select sqrt(sum(X*X)+sum(Y*Y)+sum(Z*Z)) as energy, SENSORID from data group by SENSORID order by energy desc
for doc in df:
    e=(doc['X']*doc['X'])+(doc['Y']*doc['Y'])+(doc['Z']*doc['Z'])
    if(doc['SENSORID'] not in energy):
        energy.update({doc['SENSORID']:e})
    else:
        energy.update({doc['SENSORID']:e+energy[doc['SENSORID']]})

for key, val in energy.items():
    energy.update({key:sqrt(val)})
    
res=sorted(energy.items(),key=(lambda x:x[1]),reverse=True)

pp(res)
# Out:
# [('2', 145.3616868366627), ('1', 20.524409857533055)]
